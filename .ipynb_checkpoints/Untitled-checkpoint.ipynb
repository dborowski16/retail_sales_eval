# %%
import pandas as pd
from pandas import to_datetime
import matplotlib.pyplot as plt
from fbprophet import Prophet
import datetime
import numpy as np

# %%
all_df = pd.read_json('https://retail-sales-data.herokuapp.com/alldata')

# %%
all_df.head()
# Out:
#                           DOB Gender   Item  Qty  Rate Sale/Return  \
# 0  1981-09-26 00:00:00.000000      M  01-01   -5  -772           R
# 1  1981-09-26 00:00:00.000000      M  01-01    5   772           S
# 2  1981-08-06 00:00:00.000000      M  01-01    3  1229           S
# 3  1986-10-13 00:00:00.000000      M  01-01   -4  -284           R
# 4  1986-10-13 00:00:00.000000      M  01-01    4   284           S
#
#        Store_type      Tax           city  city_code  ...  id  prod_cat  \
# 0          e-Shop  405.300  San Fransisco        5.0  ...   0  Clothing
# 1          e-Shop  405.300  San Fransisco        5.0  ...   1  Clothing
# 2  Flagship store  387.135      Las Vegas        3.0  ...   2  Clothing
# 3  Flagship store  119.280         Denver        1.0  ...   3  Clothing
# 4  Flagship store  119.280         Denver        1.0  ...   4  Clothing
#
#   prod_cat_code  prod_subcat prod_subcat_code       state total_amt  \
# 0             1        Women                1  California -4265.300
# 1             1        Women                1  California  4265.300
# 2             1        Women                1      Nevada  4074.135
# 3             1        Women                1    Colorado -1255.280
# 4             1        Women                1    Colorado  1255.280
#
#    tran_date transaction_id      zip
# 0    2014-02    80712190438  94108.0
# 1    2014-02    80712190438  94108.0
# 2    2013-12    18505840838  89107.0
# 3    2013-08    92814475704  80202.0
# 4    2013-08    92814475704  80202.0
#
# [5 rows x 21 columns]

# %%
all_df['tran_date'] = pd.to_datetime(all_df['tran_date'], format='%Y-%m-%d')
all_df['tran_date'] = all_df['tran_date'].dt.strftime('%Y-%m')
all_df.head()
# Out:
#                           DOB Gender   Item  Qty  Rate Sale/Return  \
# 0  1981-09-26 00:00:00.000000      M  01-01   -5  -772           R
# 1  1981-09-26 00:00:00.000000      M  01-01    5   772           S
# 2  1981-08-06 00:00:00.000000      M  01-01    3  1229           S
# 3  1986-10-13 00:00:00.000000      M  01-01   -4  -284           R
# 4  1986-10-13 00:00:00.000000      M  01-01    4   284           S
#
#        Store_type      Tax           city  city_code  ...  id  prod_cat  \
# 0          e-Shop  405.300  San Fransisco        5.0  ...   0  Clothing
# 1          e-Shop  405.300  San Fransisco        5.0  ...   1  Clothing
# 2  Flagship store  387.135      Las Vegas        3.0  ...   2  Clothing
# 3  Flagship store  119.280         Denver        1.0  ...   3  Clothing
# 4  Flagship store  119.280         Denver        1.0  ...   4  Clothing
#
#   prod_cat_code  prod_subcat prod_subcat_code       state total_amt  \
# 0             1        Women                1  California -4265.300
# 1             1        Women                1  California  4265.300
# 2             1        Women                1      Nevada  4074.135
# 3             1        Women                1    Colorado -1255.280
# 4             1        Women                1    Colorado  1255.280
#
#    tran_date transaction_id      zip
# 0    2014-02    80712190438  94108.0
# 1    2014-02    80712190438  94108.0
# 2    2013-12    18505840838  89107.0
# 3    2013-08    92814475704  80202.0
# 4    2013-08    92814475704  80202.0
#
# [5 rows x 21 columns]

# %%
df = all_df[all_df['Store_type'] == 'e-Shop']
df.head()
# Out:
#                            DOB Gender   Item  Qty  Rate Sale/Return  \
# 0   1981-09-26 00:00:00.000000      M  01-01   -5  -772           R
# 1   1981-09-26 00:00:00.000000      M  01-01    5   772           S
# 8   1984-07-15 00:00:00.000000      F  01-01    3  1181           S
# 10  1971-03-12 00:00:00.000000      M  01-01    2    98           S
# 12  1977-06-27 00:00:00.000000      F  01-01    5   112           S
#
#    Store_type      Tax           city  city_code  ...  id  prod_cat  \
# 0      e-Shop  405.300  San Fransisco        5.0  ...   0  Clothing
# 1      e-Shop  405.300  San Fransisco        5.0  ...   1  Clothing
# 8      e-Shop  372.015          Miami        8.0  ...   8  Clothing
# 10     e-Shop   20.580        NewYork        6.0  ...  10  Clothing
# 12     e-Shop   58.800        NewYork        6.0  ...  12  Clothing
#
#    prod_cat_code  prod_subcat prod_subcat_code       state total_amt  \
# 0              1        Women                1  California -4265.300
# 1              1        Women                1  California  4265.300
# 8              1        Women                1     Florida  3915.015
# 10             1        Women                1     NewYork   216.580
# 12             1        Women                1     NewYork   618.800
#
#     tran_date transaction_id      zip
# 0     2014-02    80712190438  94108.0
# 1     2014-02    80712190438  94108.0
# 8     2012-12    99335419136  33127.0
# 10    2012-12    24344788054  10007.0
# 12    2013-10    33886188672  10007.0
#
# [5 rows x 21 columns]

# %%
df = df[all_df['total_amt'] > 0]
df = df.loc[:,['tran_date','total_amt']].groupby('tran_date', as_index=False)['total_amt'].sum()
df.head()
# Out:
# C:\Users\dmbor\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#   tran_date    total_amt
# 0   2011-02  1255430.280
# 1   2011-03  1534258.245
# 2   2011-05  1352053.690
# 3   2011-06  1356033.900
# 4   2011-07  1485306.745

# %%
# eshop_df['tran_date'] = to_datetime(eshop_df['tran_date'])
# # eshop_df['tran_date'] = eshop_df['tran_date'].dt.to_period('M')
# eshop_df.head()
# eshop_df['ds'] = eshop_df.index
df.dtypes
# Out:
# ds    datetime64[ns]
# y            float64
# dtype: object

# %%
df.columns=['ds', 'y']
df.head()
# df['ds'] = to_datetime(df['ds'])
model = Prophet()
model.fit(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-184-dd31ac19c56b> in <module>
#       3 # df['ds'] = to_datetime(df['ds'])
#       4 model = Prophet()
# ----> 5 model.fit(df)
#
# ~\anaconda3\lib\site-packages\fbprophet\forecaster.py in fit(self, df, **kwargs)
#    1088             type) and y, the time series. If self.growth is 'logistic', then
#    1089             df must also have a column cap that specifies the capacity at
# -> 1090             each ds.
#    1091         kwargs: Additional arguments passed to the optimizing or sampling
#    1092             functions in Stan.
#
# ~\anaconda3\lib\site-packages\fbprophet\forecaster.py in setup_dataframe(self, df, initialize_scales)
#     320         df['t'] = (df['ds'] - self.start) / self.t_scale
#     321         if 'y' in df:
# --> 322             df['y_scaled'] = (df['y'] - df['floor']) / self.y_scale
#     323
#     324         for name, props in self.extra_regressors.items():
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      62
#      63         other = item_from_zerodim(other)
# ---> 64
#      65         return method(self, other)
#      66
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(left, right)
#     498                 f"dimension must be <= 2: {right.shape}"
#     499             )
# --> 500
#     501     elif is_list_like(right) and not isinstance(right, (ABCSeries, ABCDataFrame)):
#     502         # GH17901
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in arithmetic_op(left, right, op, str_rep)
#     195 def comparison_op(left: ArrayLike, right: Any, op) -> ArrayLike:
#     196     """
# --> 197     Evaluate a comparison operation `=`, `!=`, `>=`, `>`, `<=`, or `<`.
#     198
#     199     Parameters
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, str_rep)
#     147             #  In this case we do not fall back to the masked op, as that
#     148             #  will handle complex numbers incorrectly, see GH#32047
# --> 149             raise
#     150         result = masked_arith_op(left, right, op)
#     151
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     229     op_str = _op_str_mapping[op]
#     230     if op_str is not None:
# --> 231         use_numexpr = use_numexpr and _bool_arith_check(op_str, a, b)
#     232         if use_numexpr:
#     233             return _evaluate(op, op_str, a, b)  # type: ignore
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
import pystan
model_code = 'parameters {real y;} model {y ~ normal(0,1);}'
model = pystan.StanModel(model_code=model_code)  # this will take a minute
y = model.sampling(n_jobs=4).extract()['y']
y.mean()  # should be close to 0

res = model.optimizing()
print(res)  # should have `y` close to 0
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_5944b02c79788fa0db5b3a93728ca2bf NOW.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-185-440090938406> in <module>
#       1 import pystan
#       2 model_code = 'parameters {real y;} model {y ~ normal(0,1);}'
# ----> 3 model = pystan.StanModel(model_code=model_code)  # this will take a minute
#       4 y = model.sampling(n_jobs=4).extract()['y']
#       5 y.mean()  # should be close to 0
#
# ~\anaconda3\lib\site-packages\pystan\model.py in __init__(self, file, charset, model_name, model_code, stanc_ret, boost_lib, eigen_lib, verbose, obfuscate_model_name, extra_compile_args)
#     276         if include_dirs is None:
#     277             include_dirs = []
# --> 278         elif not isinstance(include_dirs, list):
#     279             raise TypeError("'include_dirs' needs to be a list: type={}".format(type(include_dirs)))
#     280         include_dirs += [
#
# ~\anaconda3\lib\site-packages\Cython\Build\Inline.py in _get_build_extension()
#     108     config_files = dist.find_config_files()
#     109     dist.parse_config_files(config_files)
# --> 110     build_extension = build_ext(dist)
#     111     build_extension.finalize_options()
#     112     return build_extension
#
# ~\anaconda3\lib\distutils\cmd.py in __init__(self, dist)
#      55
#      56         if not isinstance(dist, Distribution):
# ---> 57             raise TypeError("dist must be a Distribution instance")
#      58         if self.__class__ is Command:
#      59             raise RuntimeError("Command is an abstract class")
#
# TypeError: dist must be a Distribution instance

# %%
import distutils
print(distutils.__file__)
# Out:
# C:\Users\dmbor\anaconda3\lib\distutils\__init__.py
